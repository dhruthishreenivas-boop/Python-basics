# %% [markdown]
# <a href="https://colab.research.google.com/github/dhruthishreenivas-boop/Python-basics/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
age=int(input("enter your age:"))
if age>=18:
  print("you can vote")
else:
    print("you can't vote")
# Out:
# enter your age:15
# you can't vote

# %%
marks=int(input("enter your marks"))
if marks>=50:
  print("student is pass")
elif marks+10>=50:
  print("student passed with grace marks")
  print("grace marks added:",10)
  print("final marks:",marks+10)
else:
  print("student is fail")
# Out:
# enter your marks60
# student is pass

# %%
A=int(input("enter the value of A:"))
B=int(input("enter the value of B:"))
if A>B:
  print(A,"is large")
else:
   print(B,"is large")
# Out:
# enter the value of A:22
# enter the value of B:8
# 22 is large

# %%
text=input("enter a word or sentence:")
count=0
for ch in text:
  if ch in "aeiou":
    count=+1
    print("number of vowels.",count)
# Out:
# enter a word or sentence:i love python
# number of vowels. 1
# number of vowels. 1
# number of vowels. 1
# number of vowels. 1

# %%
a=int(input("enter frist number:"))
b=int(input("enter second number:"))
print("addition:",a+b)
print("subtraction:",a-b)
print("multiplication:",a*b)
print("division:",a/b)
# Out:
# enter frist number:10
# enter second number:20
# addition: 30
# subtraction: -10
# multiplication: 200
# division: 0.5

# %%
text=input("enter a word")
print("reversed:",text[::-1])
# Out:
# enter a wordhello world
# reversed: dlrow olleh

# %%
num=int(input("enter a number:"))
if num% 2==0:
  print("even number")
else:
  print("odd number")
# Out:
# enter a number:20
# even number
